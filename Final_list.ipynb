# %%
import pandas  as pd
import numpy as np

# %%
# pd.options.display.max_columns = none
# pd.options.display.max_rows = none
# pd.reset_option(display.max_rows)
# pd.reset_option(display.max_columns)

# %%
df=pd.read_csv(r"C:\Users\acer\Desktop\Python\airline_logical_data.csv")
df
# Out:
#         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 0                8498   SpiceJet         ATR72    CCU         MAA  2023-06-12
# 1                5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 2                1877      GoAir          B737    CCU         DEL  2023-11-30
# 3                1598      GoAir          B737    AMD         HYD  2023-06-30
# 4                2722      GoAir         ATR72    HYD         PNQ  2023-10-24
# ...               ...        ...           ...    ...         ...         ...
# 102995           2098      GoAir          A321    CCU         AMD  2023-12-06
# 102996           1978      GoAir          A321    AMD         PNQ  2023-07-21
# 102997           7474  Air India          A320    DEL         DEL  2023-08-29
# 102998           2248     IndiGo          B777    MAA         PNQ  2023-07-17
# 102999           6529   SpiceJet         ATR72    BOM         MAA  2023-05-23
#
# ...

# %%
df.head(10)
# Out:
#    Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 0           8498   SpiceJet         ATR72    CCU         MAA  2023-06-12
# 1           5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 2           1877      GoAir          B737    CCU         DEL  2023-11-30
# 3           1598      GoAir          B737    AMD         HYD  2023-06-30
# 4           2722      GoAir         ATR72    HYD         PNQ  2023-10-24
# 5           4327   SpiceJet          A321    HYD         MAA  2023-02-23
# 6           7670     IndiGo          B777    CCU         BLR  2023-02-02
# 7           4562     IndiGo          B777    DEL         PNQ  2023-08-02
# 8           1950   SpiceJet          A320    BOM         MAA  2023-04-27
# 9           1612  Air India          B777    HYD         BOM  2023-02-10
#
#    Distance_km  Duration_hours  Ticket_Price    Fuel_Cost Weather_Condition  \
# 0       1384.0        3.094867   2963.516704  3828.490167            Cloudy
# ...

# %%
df.tail(10)
# Out:
#         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 102990           5721  Air India         ATR72    DEL         AMD  2023-07-05
# 102991           5880      GoAir          A321    BOM         BLR  2023-06-17
# 102992           5006     IndiGo         ATR72    PNQ         AMD  2023-10-29
# 102993           5730      GoAir         ATR72    MAA         AMD  2023-08-01
# 102994           2368     IndiGo         ATR72    AMD         HYD  2023-05-16
# 102995           2098      GoAir          A321    CCU         AMD  2023-12-06
# 102996           1978      GoAir          A321    AMD         PNQ  2023-07-21
# 102997           7474  Air India          A320    DEL         DEL  2023-08-29
# 102998           2248     IndiGo          B777    MAA         PNQ  2023-07-17
# 102999           6529   SpiceJet         ATR72    BOM         MAA  2023-05-23
#
#         Distance_km  Duration_hours  Ticket_Price    Fuel_Cost  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103000 entries, 0 to 102999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Flight_Number      103000 non-null  int64
#  1   Airline            103000 non-null  object
#  2   Aircraft_Type      103000 non-null  object
#  3   Origin             103000 non-null  object
#  4   Destination        103000 non-null  object
#  5   Date               103000 non-null  object
#  6   Distance_km        99923 non-null   float64
#  7   Duration_hours     98884 non-null   float64
#  8   Ticket_Price       97864 non-null   float64
#  9   Fuel_Cost          99919 non-null   float64
#  10  Weather_Condition  103000 non-null  object
#  11  Delay_minutes      100939 non-null  float64
#  12  Passenger_Count    103000 non-null  int64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 10.2+ MB

# %%
df.shape
# Out:
# (103000, 13)

# %%
df.size
# Out:
# 1339000

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['Flight_Number', 'Airline', 'Aircraft_Type', 'Origin', 'Destination',
#        'Date', 'Distance_km', 'Duration_hours', 'Ticket_Price', 'Fuel_Cost',
#        'Weather_Condition', 'Delay_minutes', 'Passenger_Count'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Flight_Number',
#  'Airline',
#  'Aircraft_Type',
#  'Origin',
#  'Destination',
#  'Date',
#  'Distance_km',
#  'Duration_hours',
#  'Ticket_Price',
#  'Fuel_Cost',
#  'Weather_Condition',
#  'Delay_minutes',
#  'Passenger_Count']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=103000, step=1)

# %%
df.dtypes
# Out:
# Flight_Number          int64
# Airline               object
# Aircraft_Type         object
# Origin                object
# Destination           object
# Date                  object
# Distance_km          float64
# Duration_hours       float64
# Ticket_Price         float64
# Fuel_Cost            float64
# Weather_Condition     object
# Delay_minutes        float64
# Passenger_Count        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Flight_Number', 'Airline', 'Aircraft_Type', 'Origin', 'Destination',
#        'Date', 'Distance_km', 'Duration_hours', 'Ticket_Price', 'Fuel_Cost',
#        'Weather_Condition', 'Delay_minutes', 'Passenger_Count'],
#       dtype='object')

# %%
df.head()
# Out:
#    Flight_Number   Airline Aircraft_Type Origin Destination        Date  \
# 0           8498  SpiceJet         ATR72    CCU         MAA  2023-06-12
# 1           5263    IndiGo          A320    AMD         PNQ  2023-09-21
# 2           1877     GoAir          B737    CCU         DEL  2023-11-30
# 3           1598     GoAir          B737    AMD         HYD  2023-06-30
# 4           2722     GoAir         ATR72    HYD         PNQ  2023-10-24
#
#    Distance_km  Duration_hours  Ticket_Price    Fuel_Cost Weather_Condition  \
# 0       1384.0        3.094867   2963.516704  3828.490167            Cloudy
# 1        519.0             NaN   2912.486246  1790.502002            Cloudy
# 2       1423.0        2.112585   2177.869901  5122.704201            Cloudy
# 3        907.0        1.515557   2204.381503  3289.369504            Cloudy
# 4        529.0        1.717573   2321.112931  1543.099700             Clear
#
#    Delay_minutes  Passenger_Count
# 0       0.000000               62
# ...

# %%
df.tail()
# Out:
#         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 102995           2098      GoAir          A321    CCU         AMD  2023-12-06
# 102996           1978      GoAir          A321    AMD         PNQ  2023-07-21
# 102997           7474  Air India          A320    DEL         DEL  2023-08-29
# 102998           2248     IndiGo          B777    MAA         PNQ  2023-07-17
# 102999           6529   SpiceJet         ATR72    BOM         MAA  2023-05-23
#
#         Distance_km  Duration_hours  Ticket_Price    Fuel_Cost  \
# 102995       1753.0        2.531112   2995.180173  6435.115093
# 102996        519.0        1.137145   2971.397586  2030.405612
# 102997          0.0        0.500000   3380.840213   500.000000
# 102998        933.0        1.425115   3542.425616  3908.780885
# 102999       1056.0        2.655092   2963.984721  2977.489964
#
#        Weather_Condition  Delay_minutes  Passenger_Count
# 102995             Clear       7.730974              195
# ...

# %%
df["Airline"].value_counts()
# Out:
# Airline
# Air India    20844
# GoAir        20552
# Vistara      20552
# SpiceJet     20536
# IndiGo       20516
# Name: count, dtype: int64

# %%
df["Airline"].nunique()
# Out:
# 5

# %%
df["Airline"]
# Out:
# 0          SpiceJet
# 1            IndiGo
# 2             GoAir
# 3             GoAir
# 4             GoAir
#             ...
# 102995        GoAir
# 102996        GoAir
# 102997    Air India
# 102998       IndiGo
# 102999     SpiceJet
# Name: Airline, Length: 103000, dtype: object

# %%
df[["Airline","Aircraft_Type"]]
# Out:
#           Airline Aircraft_Type
# 0        SpiceJet         ATR72
# 1          IndiGo          A320
# 2           GoAir          B737
# 3           GoAir          B737
# 4           GoAir         ATR72
# ...           ...           ...
# 102995      GoAir          A321
# 102996      GoAir          A321
# 102997  Air India          A320
# 102998     IndiGo          B777
# 102999   SpiceJet         ATR72
#
# [103000 rows x 2 columns]

# %%
df.isna().value_counts()
# Out:
# Flight_Number  Airline  Aircraft_Type  Origin  Destination  Date   Distance_km  Duration_hours  Ticket_Price  Fuel_Cost  Weather_Condition  Delay_minutes  Passenger_Count
# False          False    False          False   False        False  False        False           False         False      False              False          False              86632
#                                                                                                 True          False      False              False          False               4583
#                                                                                 True            False         False      False              False          False               3614
#                                                                                 False           False         True       False              False          False               2684
# ...

# %%
df.isnull().count()
# Out:
# Flight_Number        103000
# Airline              103000
# Aircraft_Type        103000
# Origin               103000
# Destination          103000
# Date                 103000
# Distance_km          103000
# Duration_hours       103000
# Ticket_Price         103000
# Fuel_Cost            103000
# Weather_Condition    103000
# Delay_minutes        103000
# Passenger_Count      103000
# dtype: int64

# %%
df.isna().sum()
# Out:
# Flight_Number           0
# Airline                 0
# Aircraft_Type           0
# Origin                  0
# Destination             0
# Date                    0
# Distance_km          3077
# Duration_hours       4116
# Ticket_Price         5136
# Fuel_Cost            3081
# Weather_Condition       0
# Delay_minutes        2061
# Passenger_Count         0
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 1                5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 5                4327   SpiceJet          A321    HYD         MAA  2023-02-23
# 12               1289    Vistara          B777    CCU         PNQ  2023-04-21
# 19               6456    Vistara          A320    CCU         PNQ  2023-04-02
# 27               2665     IndiGo         ATR72    BOM         BOM  2023-09-06
# ...               ...        ...           ...    ...         ...         ...
# 102974           8047    Vistara          B777    AMD         CCU  2023-08-08
# 102979           1267     IndiGo         ATR72    HYD         BOM  2023-03-07
# 102982           4639  Air India          B777    MAA         AMD  2023-03-25
# 102983           1751      GoAir          B777    PNQ         BLR  2023-10-14
# 102994           2368     IndiGo         ATR72    AMD         HYD  2023-05-16
#
# ...

# %%
df.duplicated().sum()
# Out:
# 3000

# %%
df[df.duplicated()]
# Out:
#         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 1286             3055    Vistara          A320    DEL         BOM  2023-01-20
# 1379             2190  Air India          B777    BLR         CCU  2023-03-19
# 1651             6031      GoAir          B737    MAA         MAA  2023-12-12
# 2039             6826   SpiceJet          B777    BOM         MAA  2023-11-11
# 5034             5690  Air India         ATR72    BOM         BOM  2023-03-12
# ...               ...        ...           ...    ...         ...         ...
# 102908           8190  Air India          A321    AMD         MAA  2023-01-19
# 102930           4111     IndiGo          B777    HYD         AMD  2023-09-25
# 102944           2778      GoAir         ATR72    HYD         CCU  2023-12-19
# 102973           4501   SpiceJet          A320    MAA         BLR  2023-12-26
# 102981           8022  Air India          B737    CCU         DEL  2023-03-23
#
# ...

# %%
df.loc[df["Flight_Number"]== 1080]
# Out:
#         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 42               1080   SpiceJet          B777    BOM         AMD  2023-04-03
# 30729            1080      GoAir          B777    MAA         HYD  2023-07-11
# 43063            1080    Vistara          B777    PNQ         MAA  2023-08-13
# 47220            1080    Vistara         ATR72    AMD         HYD  2023-10-18
# 54421            1080      GoAir          A320    BOM         CCU  2023-03-28
# 70182            1080     IndiGo         ATR72    CCU         MAA  2023-03-17
# 87810            1080   SpiceJet          B777    AMD         HYD  2023-01-07
# 93435            1080     IndiGo          B777    DEL         AMD  2023-04-28
# 97978            1080   SpiceJet          A320    HYD         PNQ  2023-01-01
# 99082            1080  Air India          A320    BOM         DEL  2023-04-17
# 101087           1080   SpiceJet          B777    BOM         AMD  2023-04-03
#
# ...

# %%
df.loc[df["Flight_Number"]== 3055]
# Out:
#         Flight_Number   Airline Aircraft_Type Origin Destination        Date  \
# 128              3055   Vistara          A320    DEL         BOM  2023-01-20
# 964              3055   Vistara          A321    MAA         CCU  2023-07-06
# 1286             3055   Vistara          A320    DEL         BOM  2023-01-20
# 62054            3055  SpiceJet         ATR72    BOM         PNQ  2023-09-01
# 73258            3055     GoAir          B777    DEL         CCU  2023-07-28
# 99244            3055   Vistara         ATR72    HYD         PNQ  2023-08-26
# 101691           3055   Vistara          A321    HYD         MAA  2023-11-01
#
#         Distance_km  Duration_hours  Ticket_Price    Fuel_Cost  \
# 128          1167.0        1.914558   4150.294425  4123.110377
# 964          1384.0        2.087410   5009.495198  5086.345356
# 1286         1167.0        1.914558   4150.294425  4123.110377
# 62054         124.0        0.717344   2681.374883   500.000000
# ...

# %%
df.shape
# Out:
# (103000, 13)

# %%
df[(df["Aircraft_Type"]== "B777") & (df["Airline"]=="SpiceJet")]
# Out:
#         Flight_Number   Airline Aircraft_Type Origin Destination        Date  \
# 18               1513  SpiceJet          B777    AMD         HYD  2023-06-16
# 25               4201  SpiceJet          B777    MAA         DEL  2023-02-09
# 36               7375  SpiceJet          B777    BOM         CCU  2023-12-18
# 42               1080  SpiceJet          B777    BOM         AMD  2023-04-03
# 60               7325  SpiceJet          B777    BLR         PNQ  2023-10-22
# ...               ...       ...           ...    ...         ...         ...
# 102890           4317  SpiceJet          B777    HYD         HYD  2023-09-16
# 102891           8732  SpiceJet          B777    HYD         PNQ  2023-12-24
# 102896           7416  SpiceJet          B777    PNQ         MAA  2023-06-11
# 102901           5234  SpiceJet          B777    BOM         BLR  2023-11-12
# 102942           5476  SpiceJet          B777    MAA         MAA  2023-07-05
#
# ...

# %%
df["Aircraft_Type"].unique().tolist()
# Out:
# ['ATR72', 'A320', 'B737', 'A321', 'B777']

# %%
df[(df["Origin"]==df["Destination"]) & (df["Distance_km"]!=0.0)]
# df.query("Origin == Destination and Distance_km != 0.0")
# Out:
#         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 158              4131  Air India          B777    CCU         CCU  2023-06-21
# 694              7885  Air India          B737    BLR         BLR  2023-05-07
# 862              7651   SpiceJet          B777    BLR         BLR  2023-01-22
# 967              4371     IndiGo          A320    HYD         HYD  2023-03-11
# 1457             9955  Air India          B737    PNQ         PNQ  2023-03-15
# ...               ...        ...           ...    ...         ...         ...
# 101829           7308    Vistara          B777    AMD         AMD  2023-08-15
# 101985           2633   SpiceJet          A321    PNQ         PNQ  2023-09-01
# 102358           5122    Vistara         ATR72    PNQ         PNQ  2023-01-28
# 102370           6119     IndiGo          A320    BLR         BLR  2023-12-20
# 102739           8501     IndiGo         ATR72    BOM         BOM  2023-02-14
#
# ...

# %%
df.query("Origin == Destination and Distance_km != 0.0")

df.loc[(df["Origin"]==df["Destination"]) & (df["Distance_km"]!=0.0), "Distance_km"] = 0.0

# %%
df.query("Origin == Destination and Distance_km != 0.0")
# Out:
# Empty DataFrame
# Columns: [Flight_Number, Airline, Aircraft_Type, Origin, Destination, Date, Distance_km, Duration_hours, Ticket_Price, Fuel_Cost, Weather_Condition, Delay_minutes, Passenger_Count]
# Index: []

# %%
df.isna().sum()
# Out:
# Flight_Number           0
# Airline                 0
# Aircraft_Type           0
# Origin                  0
# Destination             0
# Date                    0
# Distance_km          2694
# Duration_hours       4116
# Ticket_Price         5136
# Fuel_Cost            3081
# Weather_Condition       0
# Delay_minutes        2061
# Passenger_Count         0
# dtype: int64

# %%
a=df[df.duplicated()]
a.to_csv("duplicates.csv")

df.drop_duplicates(inplace=True)

# %%
df.isna().sum()
# Out:
# Flight_Number           0
# Airline                 0
# Aircraft_Type           0
# Origin                  0
# Destination             0
# Date                    0
# Distance_km          2621
# Duration_hours       4000
# Ticket_Price         5000
# Fuel_Cost            3000
# Weather_Condition       0
# Delay_minutes        2000
# Passenger_Count         0
# dtype: int64

# %%
df[df["Distance_km"]==1384.00]
# Out:
#         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 0                8498   SpiceJet         ATR72    CCU         MAA  2023-06-12
# 38               8423      GoAir          A321    CCU         MAA  2023-10-19
# 52               2756     IndiGo          B737    CCU         MAA  2023-07-17
# 62               9646     IndiGo         ATR72    CCU         MAA  2023-06-28
# 68               7813     IndiGo          B777    CCU         MAA  2023-03-09
# ...               ...        ...           ...    ...         ...         ...
# 102727           6767     IndiGo          A321    MAA         CCU  2023-07-16
# 102858           3385  Air India          B777    MAA         CCU  2023-09-30
# 102926           3708      GoAir          A320    MAA         CCU  2023-09-23
# 102953           2118     IndiGo         ATR72    CCU         MAA  2023-08-20
# 102960           4747      GoAir          B737    MAA         CCU  2023-05-08
#
# ...

# %%
df["Distance_km"].unique().tolist()
# Out:
# [1384.0,
#  519.0,
#  1423.0,
#  907.0,
#  529.0,
#  516.0,
#  1601.0,
#  1186.0,
#  1056.0,
#  650.0,
#  1395.0,
#  1671.0,
#  0.0,
#  499.0,
#  297.0,
#  439.0,
#  1238.0,
#  1769.0,
#  856.0,
#  nan,
#  1762.0,
#  1753.0,
#  1747.0,
#  933.0,
#  742.0,
#  1265.0,
#  1167.0,
#  124.0,
#  1247.0,
#  806.0]

# %%
df.query("Origin == 'CCU' and Destination == 'MAA' and Distance_km != 1384.0",engine="python")
# Out:
#        Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 398             1040     IndiGo          A321    CCU         MAA  2023-07-22
# 3118            4901     IndiGo          B737    CCU         MAA  2023-08-12
# 4951            9826  Air India         ATR72    CCU         MAA  2023-04-12
# 6646            4186      GoAir          A320    CCU         MAA  2023-05-21
# 7158            2431    Vistara          B737    CCU         MAA  2023-01-10
# 9388            8541   SpiceJet          A320    CCU         MAA  2023-01-07
# 10010           8443   SpiceJet          A320    CCU         MAA  2023-11-06
# 11750           1191   SpiceJet          B737    CCU         MAA  2023-04-18
# 11912           5263  Air India          B777    CCU         MAA  2023-02-26
# 14603           3832   SpiceJet          A320    CCU         MAA  2023-01-16
# 16451           5336      GoAir         ATR72    CCU         MAA  2023-12-21
# ...

# %%
df[df["Distance_km"]==1384.0]["Origin"].unique().tolist()
# Out:
# ['CCU', 'MAA']

# %%
df[df["Distance_km"]==1384.0]["Destination"].unique().tolist()
# Out:
# ['MAA', 'CCU']

# %%
df[df["Distance_km"]==1769.0]["Origin"].unique().tolist()
# Out:
# ['MAA', 'DEL']

# %%
df[df["Distance_km"]==1769.0]["Destination"].unique().tolist()
# Out:
# ['DEL', 'MAA']

# %%
# odd == Origin Destination Distance

odd={}
li = df["Distance_km"].unique().tolist()
li.remove(0.0)
li
# Out:
# [1384.0,
#  519.0,
#  1423.0,
#  907.0,
#  529.0,
#  516.0,
#  1601.0,
#  1186.0,
#  1056.0,
#  650.0,
#  1395.0,
#  1671.0,
#  499.0,
#  297.0,
#  439.0,
#  1238.0,
#  1769.0,
#  856.0,
#  nan,
#  1762.0,
#  1753.0,
#  1747.0,
#  933.0,
#  742.0,
#  1265.0,
#  1167.0,
#  124.0,
#  1247.0,
#  806.0]

# %%
odd={}
li = df[(df["Distance_km"]!=0.0)&(df["Distance_km"].notna())]["Distance_km"].unique().tolist()
for i in li:
    org=df[df["Distance_km"]==i]["Origin"].unique().tolist()
    dest=df[df["Distance_km"]==i]["Destination"].unique().tolist()
    odd[i]=[org,dest]
odd
# Out:
# {1384.0: [['CCU', 'MAA'], ['MAA', 'CCU']],
#  519.0: [['AMD', 'PNQ'], ['PNQ', 'AMD']],
#  1423.0: [['CCU', 'DEL'], ['DEL', 'CCU']],
#  907.0: [['AMD', 'HYD'], ['HYD', 'AMD']],
#  529.0: [['HYD', 'PNQ'], ['PNQ', 'HYD']],
#  516.0: [['HYD', 'MAA'], ['MAA', 'HYD']],
#  1601.0: [['CCU', 'BLR'], ['BLR', 'CCU']],
#  1186.0: [['DEL', 'PNQ'], ['PNQ', 'DEL']],
#  1056.0: [['BOM', 'MAA'], ['MAA', 'BOM']],
#  650.0: [['HYD', 'BOM'], ['BOM', 'HYD']],
#  1395.0: [['AMD', 'MAA'], ['MAA', 'AMD']],
#  1671.0: [['CCU', 'PNQ'], ['PNQ', 'CCU']],
#  499.0: [['HYD', 'BLR'], ['BLR', 'HYD']],
#  297.0: [['MAA', 'BLR'], ['BLR', 'MAA']],
#  439.0: [['AMD', 'BOM'], ['BOM', 'AMD']],
#  1238.0: [['HYD', 'CCU'], ['CCU', 'HYD']],
#  1769.0: [['MAA', 'DEL'], ['DEL', 'MAA']],
#  856.0: [['BLR', 'BOM'], ['BOM', 'BLR']],
#  1762.0: [['BOM', 'CCU'], ['CCU', 'BOM']],
#  1753.0: [['AMD', 'CCU'], ['CCU', 'AMD']],
#  1747.0: [['DEL', 'BLR'], ['BLR', 'DEL']],
#  933.0: [['MAA', 'PNQ'], ['PNQ', 'MAA']],
# ...

# %%
for i, j in odd.items():
    df.loc[
        (df["Distance_km"] != i)
        & (df["Origin"].isin(j[0]))
        & (df["Destination"].isin(j[1]))
        & (df["Origin"] != df["Destination"]),
        "Distance_km"
    ] = i

# %%
df.isna().sum()
# Out:
# Flight_Number           0
# Airline                 0
# Aircraft_Type           0
# Origin                  0
# Destination             0
# Date                    0
# Distance_km             0
# Duration_hours       4000
# Ticket_Price         5000
# Fuel_Cost            3000
# Weather_Condition       0
# Delay_minutes        2000
# Passenger_Count         0
# dtype: int64

# %%
df.loc[(df["Distance_km"].isna())]
# Out:
# Empty DataFrame
# Columns: [Flight_Number, Airline, Aircraft_Type, Origin, Destination, Date, Distance_km, Duration_hours, Ticket_Price, Fuel_Cost, Weather_Condition, Delay_minutes, Passenger_Count]
# Index: []

# %%
df.loc[(df["Duration_hours"].isna())]
# Out:
#         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 1                5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 5                4327   SpiceJet          A321    HYD         MAA  2023-02-23
# 12               1289    Vistara          B777    CCU         PNQ  2023-04-21
# 19               6456    Vistara          A320    CCU         PNQ  2023-04-02
# 73               8547    Vistara          B777    DEL         MAA  2023-03-06
# ...               ...        ...           ...    ...         ...         ...
# 102767           5661    Vistara          B777    BOM         HYD  2023-03-11
# 102827           3981     IndiGo          B777    AMD         BOM  2023-01-13
# 102972           4010      GoAir          B737    DEL         CCU  2023-06-13
# 102982           4639  Air India          B777    MAA         AMD  2023-03-25
# 102994           2368     IndiGo         ATR72    AMD         HYD  2023-05-16
#
# ...

# %%
df.loc[df["Duration_hours"].isna() & (df["Aircraft_Type"]=="A320") & (df["Distance_km"]==519.0)]
# Out:
#        Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 1               5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 6607            6950   SpiceJet          A320    AMD         PNQ  2023-03-20
# 13394           8246      GoAir          A320    AMD         PNQ  2023-12-05
# 18000           8512  Air India          A320    AMD         PNQ  2023-07-28
# 19955           5704      GoAir          A320    PNQ         AMD  2023-12-15
# 25687           2810    Vistara          A320    AMD         PNQ  2023-05-25
# 28869           5852    Vistara          A320    AMD         PNQ  2023-01-14
# 31155           3987  Air India          A320    PNQ         AMD  2023-05-12
# 32019           3743      GoAir          A320    AMD         PNQ  2023-05-19
# 39929           1335    Vistara          A320    PNQ         AMD  2023-07-20
# 40373           7468  Air India          A320    AMD         PNQ  2023-01-24
# ...

# %%
df.loc[(df["Duration_hours"].notna()) & (df ["Aircraft_Type"]=="A320") & (df["Distance_km"]==0.0) & (df["Weather_Condition"]=="Clear")].shape
# Out:
# (1148, 13)

# %%
a=np.mean(li)
q=[]
for i in li:
    q.append(np.round(i-a))

# %%
at=df["Aircraft_Type"].unique().tolist()
at
# Out:
# ['ATR72', 'A320', 'B737', 'A321', 'B777']

# %%
df.columns
# Out:
# Index(['Flight_Number', 'Airline', 'Aircraft_Type', 'Origin', 'Destination',
#        'Date', 'Distance_km', 'Duration_hours', 'Ticket_Price', 'Fuel_Cost',
#        'Weather_Condition', 'Delay_minutes', 'Passenger_Count'],
#       dtype='object')

# %%
df.combine
# Out:
# <bound method DataFrame.combine of         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 0                8498   SpiceJet         ATR72    CCU         MAA  2023-06-12
# 1                5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 2                1877      GoAir          B737    CCU         DEL  2023-11-30
# 3                1598      GoAir          B737    AMD         HYD  2023-06-30
# 4                2722      GoAir         ATR72    HYD         PNQ  2023-10-24
# ...               ...        ...           ...    ...         ...         ...
# 102995           2098      GoAir          A321    CCU         AMD  2023-12-06
# 102996           1978      GoAir          A321    AMD         PNQ  2023-07-21
# 102997           7474  Air India          A320    DEL         DEL  2023-08-29
# 102998           2248     IndiGo          B777    MAA         PNQ  2023-07-17
# 102999           6529   SpiceJet         ATR72    BOM         MAA  2023-05-23
#
# ...

# %%
df.compare
# Out:
# <bound method DataFrame.compare of         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 0                8498   SpiceJet         ATR72    CCU         MAA  2023-06-12
# 1                5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 2                1877      GoAir          B737    CCU         DEL  2023-11-30
# 3                1598      GoAir          B737    AMD         HYD  2023-06-30
# 4                2722      GoAir         ATR72    HYD         PNQ  2023-10-24
# ...               ...        ...           ...    ...         ...         ...
# 102995           2098      GoAir          A321    CCU         AMD  2023-12-06
# 102996           1978      GoAir          A321    AMD         PNQ  2023-07-21
# 102997           7474  Air India          A320    DEL         DEL  2023-08-29
# 102998           2248     IndiGo          B777    MAA         PNQ  2023-07-17
# 102999           6529   SpiceJet         ATR72    BOM         MAA  2023-05-23
#
# ...

# %%
df.convert_dtypes()
# Out:
#         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 0                8498   SpiceJet         ATR72    CCU         MAA  2023-06-12
# 1                5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 2                1877      GoAir          B737    CCU         DEL  2023-11-30
# 3                1598      GoAir          B737    AMD         HYD  2023-06-30
# 4                2722      GoAir         ATR72    HYD         PNQ  2023-10-24
# ...               ...        ...           ...    ...         ...         ...
# 102995           2098      GoAir          A321    CCU         AMD  2023-12-06
# 102996           1978      GoAir          A321    AMD         PNQ  2023-07-21
# 102997           7474  Air India          A320    DEL         DEL  2023-08-29
# 102998           2248     IndiGo          B777    MAA         PNQ  2023-07-17
# 102999           6529   SpiceJet         ATR72    BOM         MAA  2023-05-23
#
# ...

# %%
df.corrwith
# Out:
# <bound method DataFrame.corrwith of         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 0                8498   SpiceJet         ATR72    CCU         MAA  2023-06-12
# 1                5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 2                1877      GoAir          B737    CCU         DEL  2023-11-30
# 3                1598      GoAir          B737    AMD         HYD  2023-06-30
# 4                2722      GoAir         ATR72    HYD         PNQ  2023-10-24
# ...               ...        ...           ...    ...         ...         ...
# 102995           2098      GoAir          A321    CCU         AMD  2023-12-06
# 102996           1978      GoAir          A321    AMD         PNQ  2023-07-21
# 102997           7474  Air India          A320    DEL         DEL  2023-08-29
# 102998           2248     IndiGo          B777    MAA         PNQ  2023-07-17
# 102999           6529   SpiceJet         ATR72    BOM         MAA  2023-05-23
# ...

# %%
df.corr
# Out:
# <bound method DataFrame.corr of         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 0                8498   SpiceJet         ATR72    CCU         MAA  2023-06-12
# 1                5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 2                1877      GoAir          B737    CCU         DEL  2023-11-30
# 3                1598      GoAir          B737    AMD         HYD  2023-06-30
# 4                2722      GoAir         ATR72    HYD         PNQ  2023-10-24
# ...               ...        ...           ...    ...         ...         ...
# 102995           2098      GoAir          A321    CCU         AMD  2023-12-06
# 102996           1978      GoAir          A321    AMD         PNQ  2023-07-21
# 102997           7474  Air India          A320    DEL         DEL  2023-08-29
# 102998           2248     IndiGo          B777    MAA         PNQ  2023-07-17
# 102999           6529   SpiceJet         ATR72    BOM         MAA  2023-05-23
#
# ...

# %%
df.count
# Out:
# <bound method DataFrame.count of         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 0                8498   SpiceJet         ATR72    CCU         MAA  2023-06-12
# 1                5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 2                1877      GoAir          B737    CCU         DEL  2023-11-30
# 3                1598      GoAir          B737    AMD         HYD  2023-06-30
# 4                2722      GoAir         ATR72    HYD         PNQ  2023-10-24
# ...               ...        ...           ...    ...         ...         ...
# 102995           2098      GoAir          A321    CCU         AMD  2023-12-06
# 102996           1978      GoAir          A321    AMD         PNQ  2023-07-21
# 102997           7474  Air India          A320    DEL         DEL  2023-08-29
# 102998           2248     IndiGo          B777    MAA         PNQ  2023-07-17
# 102999           6529   SpiceJet         ATR72    BOM         MAA  2023-05-23
#
# ...

# %%
df.cummax
# Out:
# <bound method DataFrame.cummax of         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 0                8498   SpiceJet         ATR72    CCU         MAA  2023-06-12
# 1                5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 2                1877      GoAir          B737    CCU         DEL  2023-11-30
# 3                1598      GoAir          B737    AMD         HYD  2023-06-30
# 4                2722      GoAir         ATR72    HYD         PNQ  2023-10-24
# ...               ...        ...           ...    ...         ...         ...
# 102995           2098      GoAir          A321    CCU         AMD  2023-12-06
# 102996           1978      GoAir          A321    AMD         PNQ  2023-07-21
# 102997           7474  Air India          A320    DEL         DEL  2023-08-29
# 102998           2248     IndiGo          B777    MAA         PNQ  2023-07-17
# 102999           6529   SpiceJet         ATR72    BOM         MAA  2023-05-23
#
# ...

# %%
df.cummin
# Out:
# <bound method DataFrame.cummin of         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 0                8498   SpiceJet         ATR72    CCU         MAA  2023-06-12
# 1                5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 2                1877      GoAir          B737    CCU         DEL  2023-11-30
# 3                1598      GoAir          B737    AMD         HYD  2023-06-30
# 4                2722      GoAir         ATR72    HYD         PNQ  2023-10-24
# ...               ...        ...           ...    ...         ...         ...
# 102995           2098      GoAir          A321    CCU         AMD  2023-12-06
# 102996           1978      GoAir          A321    AMD         PNQ  2023-07-21
# 102997           7474  Air India          A320    DEL         DEL  2023-08-29
# 102998           2248     IndiGo          B777    MAA         PNQ  2023-07-17
# 102999           6529   SpiceJet         ATR72    BOM         MAA  2023-05-23
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 0                8498   SpiceJet         ATR72    CCU         MAA  2023-06-12
# 1                5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 2                1877      GoAir          B737    CCU         DEL  2023-11-30
# 3                1598      GoAir          B737    AMD         HYD  2023-06-30
# 4                2722      GoAir         ATR72    HYD         PNQ  2023-10-24
# ...               ...        ...           ...    ...         ...         ...
# 102995           2098      GoAir          A321    CCU         AMD  2023-12-06
# 102996           1978      GoAir          A321    AMD         PNQ  2023-07-21
# 102997           7474  Air India          A320    DEL         DEL  2023-08-29
# 102998           2248     IndiGo          B777    MAA         PNQ  2023-07-17
# 102999           6529   SpiceJet         ATR72    BOM         MAA  2023-05-23
#
# ...

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 0                8498   SpiceJet         ATR72    CCU         MAA  2023-06-12
# 1                5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 2                1877      GoAir          B737    CCU         DEL  2023-11-30
# 3                1598      GoAir          B737    AMD         HYD  2023-06-30
# 4                2722      GoAir         ATR72    HYD         PNQ  2023-10-24
# ...               ...        ...           ...    ...         ...         ...
# 102995           2098      GoAir          A321    CCU         AMD  2023-12-06
# 102996           1978      GoAir          A321    AMD         PNQ  2023-07-21
# 102997           7474  Air India          A320    DEL         DEL  2023-08-29
# 102998           2248     IndiGo          B777    MAA         PNQ  2023-07-17
# 102999           6529   SpiceJet         ATR72    BOM         MAA  2023-05-23
#
# ...

# %%
df.fillna
# Out:
# <bound method NDFrame.fillna of         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 0                8498   SpiceJet         ATR72    CCU         MAA  2023-06-12
# 1                5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 2                1877      GoAir          B737    CCU         DEL  2023-11-30
# 3                1598      GoAir          B737    AMD         HYD  2023-06-30
# 4                2722      GoAir         ATR72    HYD         PNQ  2023-10-24
# ...               ...        ...           ...    ...         ...         ...
# 102995           2098      GoAir          A321    CCU         AMD  2023-12-06
# 102996           1978      GoAir          A321    AMD         PNQ  2023-07-21
# 102997           7474  Air India          A320    DEL         DEL  2023-08-29
# 102998           2248     IndiGo          B777    MAA         PNQ  2023-07-17
# 102999           6529   SpiceJet         ATR72    BOM         MAA  2023-05-23
#
# ...

# %%
df.filter
# Out:
# <bound method NDFrame.filter of         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 0                8498   SpiceJet         ATR72    CCU         MAA  2023-06-12
# 1                5263     IndiGo          A320    AMD         PNQ  2023-09-21
# 2                1877      GoAir          B737    CCU         DEL  2023-11-30
# 3                1598      GoAir          B737    AMD         HYD  2023-06-30
# 4                2722      GoAir         ATR72    HYD         PNQ  2023-10-24
# ...               ...        ...           ...    ...         ...         ...
# 102995           2098      GoAir          A321    CCU         AMD  2023-12-06
# 102996           1978      GoAir          A321    AMD         PNQ  2023-07-21
# 102997           7474  Air India          A320    DEL         DEL  2023-08-29
# 102998           2248     IndiGo          B777    MAA         PNQ  2023-07-17
# 102999           6529   SpiceJet         ATR72    BOM         MAA  2023-05-23
#
# ...

# %%
ADD = {}
for i in at:
    ADD[i] = df[(df["Aircraft_Type"]== i)]["Distance_km"].unique().tolist()

# ADD  stores values in the form {aircraft_type:[mean_distances]}

# for i,j in ADD.items():
#     for k in j:
#         li = df.loc[(df["Aircraft_Type"]== i) & (df["Distance_km"]==k)]["Weather_Condition"].unique().tolist()
#         print(i,k,li)

# we get to know that for each aircraft type and distance there are only 4 weather conditions

WC = df["Weather_Condition"].unique().tolist()
AWDD={}
for i,j in ADD.items():
    for k in j:
        for w in WC:
            me = df.loc[(df["Aircraft_Type"]== i) & (df["Distance_km"]==k) & (df["Weather_Condition"]==w)]["Duration_hours"].mean()
            AWDD[(i,k,w)]=me
AWDD
# Out:
# {('ATR72', 1384.0, 'Cloudy'): 3.2799305054201127,
#  ('ATR72', 1384.0, 'Clear'): 3.2660382235090943,
#  ('ATR72', 1384.0, 'Rainy'): 3.285693321626372,
#  ('ATR72', 1384.0, 'Foggy'): 3.276873701639284,
#  ('ATR72', 529.0, 'Cloudy'): 1.5613488593336915,
#  ('ATR72', 529.0, 'Clear'): 1.5657038761017916,
#  ('ATR72', 529.0, 'Rainy'): 1.5528355267387646,
#  ('ATR72', 529.0, 'Foggy'): 1.549125347818819,
#  ('ATR72', 1395.0, 'Cloudy'): 3.2956940155664025,
#  ('ATR72', 1395.0, 'Clear'): 3.279917688396375,
#  ('ATR72', 1395.0, 'Rainy'): 3.2815183942231503,
#  ('ATR72', 1395.0, 'Foggy'): 3.302986639724873,
#  ('ATR72', 1238.0, 'Cloudy'): 2.9738756754153264,
#  ('ATR72', 1238.0, 'Clear'): 2.98616274029379,
#  ('ATR72', 1238.0, 'Rainy'): 2.962726085009299,
#  ('ATR72', 1238.0, 'Foggy'): 2.993909877866571,
#  ('ATR72', 0.0, 'Cloudy'): 0.5434223761179411,
#  ('ATR72', 0.0, 'Clear'): 0.5389497988835725,
#  ('ATR72', 0.0, 'Rainy'): 0.5352835073749882,
#  ('ATR72', 0.0, 'Foggy'): 0.532549066776837,
# ...

# %%
n = 0.8348163062613434
h = int(n) # 3
m = int((n - h) * 60) # 2
s = int(round(((n - h) * 60 - m) * 60)) # 18

# Format as string

time_str = f"{h:02d}:{m:02d}:{s:02d}"
print(time_str)
# Out:
# 00:50:05

# %%
df.isna().sum()
# Out:
# Flight_Number           0
# Airline                 0
# Aircraft_Type           0
# Origin                  0
# Destination             0
# Date                    0
# Distance_km             0
# Duration_hours       4000
# Ticket_Price         5000
# Fuel_Cost            3000
# Weather_Condition       0
# Delay_minutes        2000
# Passenger_Count         0
# dtype: int64

# %%
for i,j in AWDD.items():
    df.loc[(df["Aircraft_Type"]== i[0]) & (df["Distance_km"]==i[1]) & (df["Weather_Condition"]==i[2]) & (df["Duration_hours"].isna()), "Duration_hours"] = j

# %%
df.iloc[9199]
# Out:
# Flight_Number               2966
# Airline                 SpiceJet
# Aircraft_Type              ATR72
# Origin                       CCU
# Destination                  MAA
# Date                  2023-02-16
# Distance_km               1384.0
# Duration_hours          3.279931
# Ticket_Price         2985.314516
# Fuel_Cost            3952.799144
# Weather_Condition         Cloudy
# Delay_minutes          15.734359
# Passenger_Count               50
# Name: 9218, dtype: object

# %%
n =   3.279931
h = int(n) # 3
m = int((n - h) * 60) # 2
s = int(round(((n - h) * 60 - m) * 60)) # 18

# Format as string

time_str = f"{h:02d}:{m:02d}:{s:02d}"
print(time_str)
# Out:
# 03:16:48

# %%
df.isna().sum()
# Out:
# Flight_Number           0
# Airline                 0
# Aircraft_Type           0
# Origin                  0
# Destination             0
# Date                    0
# Distance_km             0
# Duration_hours          0
# Ticket_Price         5000
# Fuel_Cost            3000
# Weather_Condition       0
# Delay_minutes        2000
# Passenger_Count         0
# dtype: int64

# %%
ADD
# Out:
# {'ATR72': [1384.0,
#   529.0,
#   1395.0,
#   1238.0,
#   0.0,
#   439.0,
#   1265.0,
#   1747.0,
#   124.0,
#   1601.0,
#   1186.0,
#   907.0,
#   1247.0,
#   1753.0,
#   933.0,
#   516.0,
#   1769.0,
#   519.0,
#   1423.0,
#   742.0,
#   297.0,
#   1671.0,
#   1167.0,
#   499.0,
#   856.0,
#   650.0,
#   806.0,
#   1762.0,
#   1056.0],
#  'A320': [519.0,
#   1056.0,
#   1423.0,
#   1186.0,
#   1395.0,
#   1671.0,
#   0.0,
#   742.0,
#   516.0,
#   1747.0,
#   907.0,
#   933.0,
#   856.0,
#   806.0,
#   499.0,
#   1167.0,
#   297.0,
#   1265.0,
#   529.0,
#   1753.0,
#   1238.0,
#   1769.0,
#   439.0,
#   1247.0,
#   1601.0,
#   124.0,
#   1384.0,
#   650.0,
#   1762.0],
#  'B737': [1423.0,
#   907.0,
#   516.0,
#   0.0,
#   439.0,
#   856.0,
#   1753.0,
#   933.0,
#   1384.0,
#   1167.0,
#   1762.0,
#   1395.0,
#   742.0,
#   1747.0,
#   650.0,
#   1238.0,
#   1769.0,
#   519.0,
#   124.0,
#   1671.0,
#   529.0,
#   297.0,
#   1601.0,
#   1265.0,
#   499.0,
#   1247.0,
#   1056.0,
# ...

# %%
df.loc[(df["Aircraft_Type"] == "ATR72") & (df["Distance_km"] == 1384.0)]
# Out:
#         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 0                8498   SpiceJet         ATR72    CCU         MAA  2023-06-12
# 62               9646     IndiGo         ATR72    CCU         MAA  2023-06-28
# 278              3322   SpiceJet         ATR72    MAA         CCU  2023-12-24
# 450              6915  Air India         ATR72    MAA         CCU  2023-10-09
# 681              6816    Vistara         ATR72    CCU         MAA  2023-07-28
# ...               ...        ...           ...    ...         ...         ...
# 102377           5311     IndiGo         ATR72    MAA         CCU  2023-03-07
# 102498           1109     IndiGo         ATR72    CCU         MAA  2023-05-01
# 102581           6104   SpiceJet         ATR72    CCU         MAA  2023-10-03
# 102585           8956      GoAir         ATR72    MAA         CCU  2023-03-27
# 102953           2118     IndiGo         ATR72    CCU         MAA  2023-08-20
#
# ...

# %%
for i,j in ADD.items():
    for k in j:
        me = df[(df["Aircraft_Type"]== i) & (df["Distance_km"]== k) & (df["Fuel_Cost"].notna())]["Fuel_Cost"].unique().mean()
        df.loc[(df["Aircraft_Type"]== i) & (df["Distance_km"]== k) & (df["Fuel_Cost"].isna()), "Fuel_Cost"] = me

# %%
df.isna().sum()
# Out:
# Flight_Number           0
# Airline                 0
# Aircraft_Type           0
# Origin                  0
# Destination             0
# Date                    0
# Distance_km             0
# Duration_hours          0
# Ticket_Price         5000
# Fuel_Cost               0
# Weather_Condition       0
# Delay_minutes        2000
# Passenger_Count         0
# dtype: int64

# %%
air = df["Airline"].unique().tolist()
ADD

for i,j in ADD.items():
    for k in j:
        for a in air:
            me = df[(df["Aircraft_Type"] == i) & (df["Distance_km"] == k) & (df["Airline"] == a) & (df["Ticket_Price"].notna())]["Ticket_Price"].mean()
            df.loc[(df["Aircraft_Type"] == i) & (df["Distance_km"] == k) & (df["Airline"] == a) & (df["Ticket_Price"].isna()), "Ticket_Price"] = me

# %%
df.isna().sum()
# Out:
# Flight_Number           0
# Airline                 0
# Aircraft_Type           0
# Origin                  0
# Destination             0
# Date                    0
# Distance_km             0
# Duration_hours          0
# Ticket_Price            0
# Fuel_Cost               0
# Weather_Condition       0
# Delay_minutes        2000
# Passenger_Count         0
# dtype: int64

# %%
df[df["Delay_minutes"].isna()]
# Out:
#         Flight_Number    Airline Aircraft_Type Origin Destination        Date  \
# 34               4477    Vistara          A320    BLR         PNQ  2023-02-06
# 48               3472  Air India          A321    PNQ         DEL  2023-01-16
# 153              5908  Air India          A320    MAA         AMD  2023-10-09
# 183              4226      GoAir          B737    CCU         MAA  2023-04-24
# 226              7444  Air India          A321    BOM         CCU  2023-06-16
# ...               ...        ...           ...    ...         ...         ...
# 102712           1006     IndiGo          B777    CCU         HYD  2023-12-24
# 102757           8207     IndiGo          B737    PNQ         BLR  2023-01-26
# 102825           4254    Vistara          A320    HYD         CCU  2023-05-14
# 102868           3464    Vistara          A321    BOM         MAA  2023-10-09
# 102949           1530   SpiceJet          A320    DEL         BOM  2023-05-29
#
# ...

# %%
WDD = {"Cloudy":[3,8], "Clear":[1,5], "Foggy":[5,10], "Rainy":[10,15]}
di = df["Distance_km"].unique().tolist()
BBD = {}
for i in di:
    a = np.round(i/100)
    BBD[i] = a
BBD
# Out:
# {1384.0: 14.0,
#  519.0: 5.0,
#  1423.0: 14.0,
#  907.0: 9.0,
#  529.0: 5.0,
#  516.0: 5.0,
#  1601.0: 16.0,
#  1186.0: 12.0,
#  1056.0: 11.0,
#  650.0: 6.0,
#  1395.0: 14.0,
#  1671.0: 17.0,
#  0.0: 0.0,
#  499.0: 5.0,
#  297.0: 3.0,
#  439.0: 4.0,
#  1238.0: 12.0,
#  1769.0: 18.0,
#  856.0: 9.0,
#  742.0: 7.0,
#  1762.0: 18.0,
#  1753.0: 18.0,
#  1747.0: 17.0,
#  933.0: 9.0,
#  1265.0: 13.0,
#  1167.0: 12.0,
#  124.0: 1.0,
#  1247.0: 12.0,
#  806.0: 8.0}

# %%
a = 1251.0
np.round(a/100)
# Out:
# 13.0

# %%
di = df["Distance_km"].unique().tolist()
BBD = {}
for i in di:
    a = np.round(i/100)
    BBD[i] = a
BBD
# Out:
# {1384.0: 14.0,
#  519.0: 5.0,
#  1423.0: 14.0,
#  907.0: 9.0,
#  529.0: 5.0,
#  516.0: 5.0,
#  1601.0: 16.0,
#  1186.0: 12.0,
#  1056.0: 11.0,
#  650.0: 6.0,
#  1395.0: 14.0,
#  1671.0: 17.0,
#  0.0: 0.0,
#  499.0: 5.0,
#  297.0: 3.0,
#  439.0: 4.0,
#  1238.0: 12.0,
#  1769.0: 18.0,
#  856.0: 9.0,
#  742.0: 7.0,
#  1762.0: 18.0,
#  1753.0: 18.0,
#  1747.0: 17.0,
#  933.0: 9.0,
#  1265.0: 13.0,
#  1167.0: 12.0,
#  124.0: 1.0,
#  1247.0: 12.0,
#  806.0: 8.0}

# %%
WDD = {"Cloudy":[3,8], "Clear":[1,5], "Foggy":[5,10], "Rainy":[10,15]}
di = df["Distance_km"].unique().tolist()
BBD = {}
for i in di:
    a = np.round(i/100)
    BBD[i] = a
BBD
for i,j in BBD.items():
    for m,n in WDD.items():
        if m == "Clear":
            df.loc[(df["Distance_km"] == i) & (df["Weather_Condition"] == m) & (df["Delay_minutes"].isna()),
                   "Delay_minutes"] = np.random.choice(df[(df["Distance_km"] == i) & (df["Weather_Condition"] == m) & (df["Delay_minutes"].notna()) & 
                                                          (df["Delay_minutes"] >= 0.0) &
                                                          (df["Delay_minutes"] <=j+np.random.randint(n[0],n[1]))]["Delay_minutes"].unique().tolist())
            
        elif m == "Cloudy":
            df.loc[(df["Distance_km"] == i) & (df["Weather_Condition"] == m) & (df["Delay_minutes"].isna()),
                   "Delay_minutes"] = np.random.choice(df[(df["Distance_km"] == i) & (df["Weather_Condition"] == m) & (df["Delay_minutes"].notna()) & 
                                                          (df["Delay_minutes"] >= j-np.random.randint(n[0],n[1])) &
                                                          (df["Delay_minutes"] <=j+np.random.randint(n[0],n[1]))]["Delay_minutes"].unique().tolist())
            
        elif m == "Foggy":
            df.loc[(df["Distance_km"] == i) & (df["Weather_Condition"] == m) & (df["Delay_minutes"].isna()),
                   "Delay_minutes"] = np.random.choice(df[(df["Distance_km"] == i) & (df["Weather_Condition"] == m) & (df["Delay_minutes"].notna())]
                                                          ["Delay_minutes"].unique().tolist())
            
        elif m == "Rainy":
            df.loc[(df["Distance_km"] == i) & (df["Weather_Condition"] == m) & (df["Delay_minutes"].isna()),
                   "Delay_minutes"] = np.random.choice(df[(df["Distance_km"] == i) & (df["Weather_Condition"] == m) & (df["Delay_minutes"].notna()) & 
                                                          (df["Delay_minutes"] >= j) &
                                                          (df["Delay_minutes"] <=2*j+(np.random.randint(n[0],n[1])))]["Delay_minutes"].unique().tolist())

# %%
df.isna().sum()
# Out:
# Flight_Number        0
# Airline              0
# Aircraft_Type        0
# Origin               0
# Destination          0
# Date                 0
# Distance_km          0
# Duration_hours       0
# Ticket_Price         0
# Fuel_Cost            0
# Weather_Condition    0
# Delay_minutes        0
# Passenger_Count      0
# dtype: int64

# %%
# WDD = {"Cloudy":[1,5], "Clear":[1,5], "Foggy":[5,10], "Rainy":[10,15]}


# di = df["Distance_km"].unique().tolist()
# BBD = {}
# for i in di:
#     a = np.round(i/100)   
#     BBD[i] = a


# WC = df["Weather_Condition"].unique().tolist()


# if "Delay_minutes" not in df.columns:
#     df["Delay_minutes"] = np.nan


# for dist_val, dist_factor in BBD.items():
#     for weather in WC:

#         w_range = WDD.get(weather, [1, 5])
#         w_min, w_max = w_range[0], w_range[1]
        

#         mask = (
#             (df["Distance_km"] == dist_val) &
#             (df["Weather_Condition"] == weather) &
#             (df["Delay_minutes"].isna())
#         )


#         n = mask.sum()
#         if n == 0:
#             continue


#         base_delays = np.random.uniform(low=w_min, high=w_max, size=n)


#         final_delays = base_delays * (dist_factor / 5.0)

#         final_delays = np.round(final_delays, 2)

        
#         df.loc[mask, "Delay_minutes"] = final_delays

# %%
df.isna().sum()
# Out:
# Flight_Number        0
# Airline              0
# Aircraft_Type        0
# Origin               0
# Destination          0
# Date                 0
# Distance_km          0
# Duration_hours       0
# Ticket_Price         0
# Fuel_Cost            0
# Weather_Condition    0
# Delay_minutes        0
# Passenger_Count      0
# dtype: int64

# %%
# air_delay = df["Airline"].unique().tolist()
# ADD

# for i,j in ADD.items():
#     for k in j:
#         for a in air_delay:
#             me = df[(df["Aircraft_Type"] == i) & (df["Distance_km"] == k) & (df["Airline"] == a) & (df["Delay_minutes"].notna())]["Delay_minutes"].mean()
#             df.loc[(df["Aircraft_Type"] == i) & (df["Distance_km"] == k) & (df["Airline"] == a) & (df["Delay_minutes"].isna()), "Delay_minutes"] = me

# %%
# df[df["Delay_minutes"].isna()]

# %%
df.iloc[102975:]
# Out:
# Empty DataFrame
# Columns: [Flight_Number, Airline, Aircraft_Type, Origin, Destination, Date, Distance_km, Duration_hours, Ticket_Price, Fuel_Cost, Weather_Condition, Delay_minutes, Passenger_Count]
# Index: []

# %%
df.loc[(df["Flight_Number"]==8047)& (df["Airline"]=="Vistara")]
# Out:
#         Flight_Number  Airline Aircraft_Type Origin Destination        Date  \
# 83304            8047  Vistara          A320    AMD         BOM  2023-03-05
# 102974           8047  Vistara          B777    AMD         CCU  2023-08-08
#
#         Distance_km  Duration_hours  Ticket_Price    Fuel_Cost  \
# 83304         439.0        1.158153   3960.313385  1507.588273
# 102974       1753.0        2.533563   5143.983572  7359.807145
#
#        Weather_Condition  Delay_minutes  Passenger_Count
# 83304              Clear       4.485186              128
# 102974            Cloudy      27.171770              252

# %%
def fnc(n):
    h=int(n)
    m=int((n-h)*60)
    s=int(round((n-h)*60 -m ) * 60)

    time_str=f"{h:02d}:{m:02d}:{s:02d}"
    return time_str

df["Duration_hours"]=df["Duration_hours"].apply(lambda x: fnc(x))

# %%
df.loc[(df["Flight_Number"]==8047)& (df["Airline"]=="Vistara")]
# Out:
#         Flight_Number  Airline Aircraft_Type Origin Destination        Date  \
# 83304            8047  Vistara          A320    AMD         BOM  2023-03-05
# 102974           8047  Vistara          B777    AMD         CCU  2023-08-08
#
#         Distance_km Duration_hours  Ticket_Price    Fuel_Cost  \
# 83304         439.0       01:09:00   3960.313385  1507.588273
# 102974       1753.0       02:32:00   5143.983572  7359.807145
#
#        Weather_Condition  Delay_minutes  Passenger_Count
# 83304              Clear       4.485186              128
# 102974            Cloudy      27.171770              252

# %%
def fnc(n):
    m=int(n)
    s=int((n-m)*60)
    

    time_str=f"{m:03d}:{s:03d}"
    return time_str

df["Delay_minutes"]=df["Delay_minutes"].apply(lambda x: fnc(x))

# %%
df.loc[(df["Flight_Number"]==8047)& (df["Airline"]=="Vistara")]
# Out:
#         Flight_Number  Airline Aircraft_Type Origin Destination        Date  \
# 83304            8047  Vistara          A320    AMD         BOM  2023-03-05
# 102974           8047  Vistara          B777    AMD         CCU  2023-08-08
#
#         Distance_km Duration_hours  Ticket_Price    Fuel_Cost  \
# 83304         439.0       01:09:00   3960.313385  1507.588273
# 102974       1753.0       02:32:00   5143.983572  7359.807145
#
#        Weather_Condition Delay_minutes  Passenger_Count
# 83304              Clear       004:029              128
# 102974            Cloudy       027:010              252

# %%
df.to_csv("cleaned airline data.csv",index=False)
